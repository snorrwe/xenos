# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 10]

df = pd.read_csv("cpus.csv")
df['Bucket %'] = df['Bucket'] / 100
df ["Time"] = pd.to_datetime(df['Time'])
df.drop('Bucket', axis=1, inplace=True)
df.plot(x="Time")
df.describe()
# Out:
#               CPU    Bucket %
# count  211.000000  211.000000
# mean    15.530408   99.222417
# std     41.420814    1.963724
# min      2.534300   92.790000
# 25%      2.914250   98.410000
# 50%      3.166600  100.000000
# 75%      4.153650  100.000000
# max    211.197700  110.000000
